# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('mobile_data_flipkart_scraping.csv')

# %%
df.index=list(range(1,468))

# %%
df
# Out:
#      Unnamed: 0                                            Product  Ratings  \
# 1             0                 realme C11 2021 (Cool Grey, 32 GB)      4.4
# 2             1                 realme C11 2021 (Cool Grey, 64 GB)      4.3
# 3             2                 realme C11 2021 (Cool Blue, 32 GB)      4.4
# 4             3                 realme C11 2021 (Cool Blue, 64 GB)      4.3
# 5             4                       POCO C31 (Royal Blue, 64 GB)      4.4
# ..          ...                                                ...      ...
# 463         475                      vivo Y1s (Aurora Blue, 32 GB)      4.3
# 464         476  MarQ by Flipkart M3 Smart (M3) (Blue,32GB)( 2G...      3.9
# 465         477                    vivo Y12G (Glacier Blue, 64 GB)      4.3
# 466         478         SAMSUNG Galaxy A53 (Awesome Black, 128 GB)      4.1
# 467         479                       POCO M4 Pro (Yellow, 128 GB)      4.3
#
# ...

# %%
budget_10k=[]
for i in df['Price']:
    if i<=10000:
        budget_10k.append('Yes')
    else:
        budget_10k.append('No')

# %%
budget_50k=[]
for i in df['Price']:
    if i>=50000:
        budget_50k.append('Yes')
    else:
        budget_50k.append('No')

# %%
df['Budget_below_10k']=budget_10k
df['Budget_above_50k']=budget_50k

# %%
df.plot.scatter('Price','Current_Offer')
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Current_Offer'>

# %%
df.boxplot(column='Price',by='Current_Offer')
# Out:
# <AxesSubplot:title={'center':'Price'}, xlabel='Current_Offer'>

# %%
import matplotlib.style
matplotlib.style.use('ggplot')
plt.plot(df['Price'][0:30],color='r')
plt.text(20,18000,'Testing')
plt.ylabel('Prices')
# Out:
# Text(0, 0.5, 'Prices')

# %%
plt.pie(df['Price'][0:15],labels=df['Price'][0:15])
plt.show()

# %%
plt.violinplot(df['Price'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1793ff1e130>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1793ff0ffa0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1793ff1e670>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1793ff1e9a0>}

# %%
plt.figure(figsize=(15,7))
plt.scatter(df['Brand'],df['Price'])

# %%
plt.figure(figsize=(15,7))
plt.scatter(df['Brand'],df['Current_Offer'])

# %%
plt.hist(df['Price'])
# Out:
# (array([113., 173.,  80.,  25.,   8.,   6.,   5.,   2.,   7.,  10.]),
#  array([ 3684. , 10805.6, 17927.2, 25048.8, 32170.4, 39292. , 46413.6,
#         53535.2, 60656.8, 67778.4, 74900. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.bar(df['Current_Offer'],df['Ratings'])
# Out:
# <BarContainer object of 429 artists>

# %%
plt.figure(figsize=(15,7))
sns.boxplot(x=df.Brand,y=df.Price)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Price'>

# %%
plt.figure(figsize=(15,7))
sns.pointplot(x=df.Brand,y=df.Price)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Price'>

# %%
sns.heatmap(df[['Price','Ratings']])
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df[['Current_Offer','Ratings']])
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)
