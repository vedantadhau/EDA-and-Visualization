# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.style

# %%
df=pd.read_csv('final_without_index.csv',index_col=0)

# %%
df.isnull().sum()
# Out:
# Ratings                              0
# Price                                0
# Current_Offer                        0
# Brand                                0
# Budget_below_10k                     0
# Budget_above_50k                     0
# RAM in GB                            0
# Storage in GB                        0
# Warranty_for_accessories_in_month    0
# Battery_in_mAh                       0
# Warranty_for_handset_in_years        1
# Size_in_inches                       5
# dtype: int64

# %%
df.dropna(how='any',subset=['Size_in_inches','Warranty_for_handset_in_years'],inplace=True)

# %%
df
# Out:
#      Ratings    Price  Current_Offer    Brand Budget_below_10k  \
# 0        4.4   7499.0              6   realme              Yes
# 1        4.3   8999.0             10   realme              Yes
# 2        4.4   7499.0              6   realme              Yes
# 3        4.3   8999.0             10   realme              Yes
# 4        4.4   8999.0             25     POCO              Yes
# ..       ...      ...            ...      ...              ...
# 461      4.2  26999.0             15   Xiaomi               No
# 462      4.3   9490.0             20     vivo              Yes
# 463      3.9   5999.0              7     MarQ              Yes
# 464      4.3  12990.0              0     vivo               No
# 465      4.1  35999.0              9  SAMSUNG               No
#
#     Budget_above_50k  RAM in GB  Storage in GB  \
# 0                 No          2             32
# 1                 No          4             64
# 2                 No          2             32
# ...

# %% [markdown]
# ## UNIVARIATE  PLOT

# %%
plt.figure(figsize=(20,13))
plt.style.use('ggplot')

plt.subplot(331)
plt.plot(df.Price)
plt.title('Prices')

plt.subplot(332)
plt.plot(df.Ratings)
plt.ylim(3,5)
plt.title('Ratings')

plt.subplot(333)
plt.plot(df.Current_Offer)
plt.title('Offers')

plt.subplot(334)
plt.plot(df['RAM in GB'])
plt.title('RAM')

plt.subplot(335)
plt.plot(df['Storage in GB'])
plt.title('ROM')

plt.subplot(336)
plt.plot(df['Warranty_for_accessories_in_month'])
plt.title('Warranty_for_accessories')

plt.subplot(337)
plt.plot(df['Battery_in_mAh'])
plt.title('Battery')

plt.subplot(338)
plt.plot(df['Warranty_for_handset_in_years'])
plt.title('Warranty_for_handset')

plt.subplot(339)
plt.plot(df['Size_in_inches'])
plt.title('Size')
# Out:
# Text(0.5, 1.0, 'Size')

# %%
plt.pie(df['Price'][0:10],labels=df['Price'][0:10])
plt.show
plt.title('PiePlot')
# Out:
# Text(0.5, 1.0, 'PiePlot')

# %%
plt.violinplot(df['Price'])
plt.ylim(0,50000)
# Out:
# (0.0, 50000.0)

# %%
plt.hist(df['Price'])
# Out:
# (array([380.,  49.,  14.,  10.,   7.,   0.,   0.,   0.,   0.,   1.]),
#  array([  5688. ,  21109.2,  36530.4,  51951.6,  67372.8,  82794. ,
#          98215.2, 113636.4, 129057.6, 144478.8, 159900. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(15,7))
sns.countplot(y=df['Brand'])
plt.title('BarPlot')
# Out:
# Text(0.5, 1.0, 'BarPlot')

# %% [markdown]
# ### Bivariate Plots

# %%
plt.figure(figsize=(15,7))
plt.scatter(df['Brand'],df['Price'])
plt.title('ScatterPlot')
# Out:
# Text(0.5, 1.0, 'ScatterPlot')

# %%
plt.figure(figsize=(15,7))
plt.bar(df['Brand'],df['Price'],color='g')
plt.ylim(0,100000)

plt.title('2D_BarPlot')
# Out:
# Text(0.5, 1.0, '2D_BarPlot')

# %%
plt.figure(figsize=(15,7))
plt.bar(df['Brand'],df['Current_Offer'])
# Out:
# <BarContainer object of 461 artists>

# %%
plt.figure(1,figsize=(15,7))
plt.bar(df['Brand'],df['RAM in GB'],color='g')
plt.show()

# %%
plt.figure(1,figsize=(15,7))
plt.bar(df['Brand'],df['Storage in GB'],color='r')
plt.show()

# %%
plt.figure(1,figsize=(15,7))
plt.bar(df['Brand'],df['Price'],color='b')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.boxplot(x=df['Brand'],y=df['Price'])
plt.title('BoxPlot')
# Out:
# Text(0.5, 1.0, 'BoxPlot')

# %%
plt.figure(figsize=(15,7))
sns.boxplot(x=df['Brand'],y=df['Current_Offer'])
plt.title('BoxPlot')
# Out:
# Text(0.5, 1.0, 'BoxPlot')

# %%
plt.figure(figsize=(15,7))
sns.boxplot(x=df['Brand'],y=df['Battery_in_mAh'])
plt.title('BoxPlot')
# Out:
# Text(0.5, 1.0, 'BoxPlot')

# %%
plt.figure(figsize=(15,7))
sns.boxplot(x=df['Brand'],y=df['Size_in_inches'])
plt.title('BoxPlot')
# Out:
# Text(0.5, 1.0, 'BoxPlot')

# %%
plt.figure(figsize=(15,7))
sns.violinplot(x=df['Brand'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Price'>

# %%
plt.figure(figsize=(15,7))
sns.pointplot(x=df['Brand'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Price'>

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x=df['Brand'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Price'>

# %%
plt.figure(figsize=(15,7))
sns.barplot(x=df['Brand'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Price'>

# %%
plt.figure(figsize=(15,7))
sns.swarmplot(x=df['Brand'],y=df['Price'])
# Out:
# C:\Users\adhau\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 44.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\adhau\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 20.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\adhau\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 32.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\adhau\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 11.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.heatmap(df[['Price','Current_Offer']])
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df.Price[0:10])
# Out:
# C:\Users\adhau\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sns.jointplot(x=df.Price,y=df.Battery_in_mAh)

# %%
sns.pairplot(df)
